# %%
# !pip install roboflow
from roboflow import Roboflow
rf = Roboflow(api_key="K8tPVu886f0HjELHygn6")
project = rf.workspace("school-fuhih").project("vietnamese-license-plate-tptd0")
version = project.version(1)
dataset = version.download("yolov12")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...

# %%
import os
dataset_path = dataset.location

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO
model = YOLO('yolo12s.pt')
results = model.train(
    data=os.path.join(dataset_path, 'data.yaml'),
    epochs=50,
    imgsz=640,
    batch=16,
    name="nhandien_bienso_vn")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.4.38 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
from ultralytics import YOLO
from google.colab import drive
import os

drive.mount('/content/drive')
model_path = '/content/drive/MyDrive/Do_An_DeepLearning/last.pt'
model = YOLO(model_path)
model.train(
    resume=True,
    project='/content/drive/MyDrive/Do_An_DeepLearning',
    name='nhandien_bienso_vn',
    data=os.path.join(dataset_path, 'data.yaml'),
    )
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Ultralytics 8.4.39 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
from ultralytics import YOLO
from PIL import Image
from google.colab import drive
drive.mount('/content/drive')
model = YOLO('/content/drive/MyDrive/Do_An_DeepLearning/best.pt')
results = model('test.jpg',conf=0.4, iou=0.4)
for r in results:
    im_array = r.plot()
    im = Image.fromarray(im_array[..., ::-1])
    display(im)
    print("-" * 30)
    if len(r.boxes) > 0:
        print("ĐÃ TÌM THẤY BIỂN SỐ!")
        print("Tọa độ cắt ảnh (x1, y1, x2, y2):", r.boxes.xyxy[0].tolist())
        print("Độ tin cậy (Confidence):", r.boxes.conf[0].item())
    else:
        print("Mô hình không thấy biển số nào trong ảnh này.")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#
# image 1/1 /content/test.jpg: 640x480 1 0, 566.4ms
# Speed: 3.9ms preprocess, 566.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# <PIL.Image.Image image mode=RGB size=1000x1333>
# ------------------------------
# ĐÃ TÌM THẤY BIỂN SỐ!
# Tọa độ cắt ảnh (x1, y1, x2, y2): [92.83447265625, 307.4099426269531, 870.6366577148438, 869.7709350585938]
# Độ tin cậy (Confidence): 0.536838710308075

# %%
import cv2
from google.colab.patches import cv2_imshow
img = cv2.imread('test.jpg')
box = results[0].boxes.xyxy[0].cpu().numpy().astype(int)
x1, y1, x2, y2 = box
bien_so_cat_duoc = img[y1:y2, x1:x2]
print("Tọa độ khung xanh:", box)
cv2_imshow(bien_so_cat_duoc)
cv2.imwrite('bien_so_crop.jpg', bien_so_cat_duoc)
# Out:
# Tọa độ khung xanh: [ 92 307 870 869]
# <PIL.Image.Image image mode=RGB size=778x562>
# True

# %%
# !pip install easyocr
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 24.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 180.7/180.7 kB 11.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 978.2/978.2 kB 31.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.6/300.6 kB 19.6 MB/s eta 0:00:00
# ...

# %%
import easyocr
print("Đang tải mô hình ngôn ngữ, đợi một chút nhé...")
reader = easyocr.Reader(['vi', 'en'], gpu=True)
ket_qua = reader.readtext('bien_so_crop.jpg')
print("\n--- KẾT QUẢ ĐỌC BIỂN SỐ ---")
bien_so_hoan_chinh = ""

for (toado_chu, text, do_tin_cay) in ket_qua:
    print(f"Phát hiện dòng: '{text}' | Độ tin cậy: {do_tin_cay:.2f}")
    chuoi_sach = "".join(e for e in text if e.isalnum())
    bien_so_hoan_chinh += chuoi_sach + "-"
print("-" * 30)
print(f" BIỂN SỐ CUỐI CÙNG: {bien_so_hoan_chinh.strip('-')} ")
# Out:
# WARNING:easyocr.easyocr:Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# WARNING:easyocr.easyocr:Downloading detection model, please wait. This may take several minutes depending upon your network connection.
# Đang tải mô hình ngôn ngữ, đợi một chút nhé...
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# WARNING:easyocr.easyocr:Downloading recognition model, please wait. This may take several minutes depending upon your network connection.
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
# --- KẾT QUẢ ĐỌC BIỂN SỐ ---
# Phát hiện dòng: '59' | Độ tin cậy: 1.00
# Phát hiện dòng: 'V2' | Độ tin cậy: 0.37
# Phát hiện dòng: '544.11' | Độ tin cậy: 0.94
# ------------------------------
#  BIỂN SỐ CUỐI CÙNG: 59-V2-54411
